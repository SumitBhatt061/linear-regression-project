# %% [markdown]
# <a href="https://colab.research.google.com/github/SumitBhatt061/linear-regression-project/blob/main/Simple_linear_salary_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#y = mx + c
#y = b1x + b0

# %%
import pandas as pd

# %%
data=pd.read_csv("Salary_Data.csv")

# %%
#y=salary(dependent variable/output)
#x=experience(independent/input)
data
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
X=data[["YearsExperience"]]
y=data["Salary"]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot(X,y,'r*')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.30,random_state=0)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr.intercept_)#value of c
# Out:
# 26777.391341197625

# %%
print(lr.coef_)#value of m
# Out:
# [9360.26128619]

# %%
y_pred=lr.predict(X_test)

# %%
y_pred
# Out:
# array([ 40817.78327049, 123188.08258899,  65154.46261459,  63282.41035735,
#        115699.87356004, 108211.66453108, 116635.89968866,  64218.43648597,
#         76386.77615802])

# %%
y_test.values
# Out:
# array([ 37731., 122391.,  57081.,  63218., 116969., 109431., 112635.,
#         55794.,  83088.])

# %%
plt.plot(X_test,y_test,'r*')
plt.plot(X_test,y_pred,c='black')

# %%
#evaluate
from sklearn import metrics

# %%
print(metrics.mean_absolute_error(y_test,y_pred))
# Out:
# 3737.417861878896

# %%
from sklearn.metrics import mean_squared_error

# %%
print(mean_squared_error(y_test,y_pred))
# Out:
# 23370078.800832972
